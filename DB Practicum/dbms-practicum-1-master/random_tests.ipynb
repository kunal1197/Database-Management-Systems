# %%
import pandas as pd

# %%
flight = pd.read_csv("Flight.csv")

# %%
flight[flight['flightDate'].str.contains("2008")][flight['phaseOfFlight'].isin(['Climb', 'Descent', 'Approach',
                                                                               'Landing Roll', 'Take-off run'])]
# Out:
# <ipython-input-5-89c81c79653c>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   flight[flight['flightDate'].str.contains("2008")][flight['phaseOfFlight'].isin(['Climb', 'Descent', 'Approach',
#        aircraftID  airportID  altitudeID  recordID skyCondition phaseOfFlight  \
# 2405          120         61           2    252120     No Cloud  Take-off run
# 2406           23         77          36    252543     No Cloud      Approach
# 2407           37        106          97    253554     No Cloud      Approach
# 2408          310         61           5    253524     No Cloud         Climb
# 2409          176         81           5    253912     Overcast         Climb
# ...           ...        ...         ...       ...          ...           ...
# 17773         183        178          15    259595   Some Cloud         Climb
# 17774         120         31          17    256894   Some Cloud      Approach
# ...
